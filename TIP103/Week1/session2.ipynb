# %%
# Transpose Matrix

"""
Understand: Rows will become columns, and columns will become rows. Input being a 2D array
Plan: 
Implement:
"""


def transpose(matrix):
    n = len(matrix)
    m = len(matrix[0])
    
    for i in range(m):
        for j in range(i, n):
            temp = matrix[i][j]

    return matrix



    


matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
print(transpose(matrix))
matrix = [
    [1, 2, 3],
    [4, 5, 6]
]
print(transpose(matrix))
# Out:
# None
# None

# %%
def reverse_list(lst):
    l = 0
    r = len(lst) -1

    while l < r:
        lst[l], lst[r] = lst[r], lst[l]

        l += 1
        r -= 1

    return lst

lst = ["pooh", "christopher robin", "piglet", "roo", "eeyore"]
print(reverse_list(lst))
# Out:
# ['eeyore', 'roo', 'piglet', 'christopher robin', 'pooh']

# %%
def remove_dupes(items):

    hm = {}

    for i in range(len(items)):
        if items[i] in hm:
            items.pop(hm[items[i]])

        else:
            hm[i] = items[i]
    
    return len(items)


items = ["extract of malt", "haycorns", "honey", "thistle", "thistle"]
print(remove_dupes(items))

items = ["extract of malt", "haycorns", "honey", "thistle"]
print(remove_dupes(items))
# Out:
# 5
# 4
