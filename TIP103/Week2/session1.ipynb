# %%
def total_treasure(treasure_map):
    
    total = 0

    for key in treasure_map:
        total += treasure_map[key]

    return total


treasure_map1 = {
    "Cove": 3,
    "Beach": 7,
    "Forest": 5
}

print(total_treasure(treasure_map1))
treasure_map2 = {
    "Shipwreck": 10,
    "Cave": 20,
    "Lagoon": 15,
    "Island Peak": 5}

print(total_treasure(treasure_map2))
# Out:
# 15
# 50

# %%
def can_trust_message(message):
    alphabet = set()

    for letter in message.replace(" ", ""):
        alphabet.add(letter)

    if len(alphabet) == 26:
        return True
    
    return False


message1 = "sphinx of black quartz judge my vow"
message2 = "trust me"
message3 = "abcdefghijklmnopqrstuvwxyz"

print(can_trust_message(message1))
print(can_trust_message(message2))
print(can_trust_message(message3))
# Out:
# True
# False
# True

# %%
from collections import Counter

def find_duplicate_chests(chests):

    rep = Counter(chests)
    result = set()

    for key in rep:
        if rep[key] >= 2:
            result.add(key)

    return sorted(result)


chests1 = [4, 3, 2, 7, 8, 2, 3, 1]
chests2 = [1, 1, 2]
chests3 = [1]

print(find_duplicate_chests(chests1))
print(find_duplicate_chests(chests2))
print(find_duplicate_chests(chests3))
# Out:
# [2, 3]
# [1]
# []

# %%
# frequency map and keep a counter of how many letters have a frequency more than 1, if counter > 2 then false
# only works for this specific problem

from collections import Counter

def can_make_balanced(code):
    rep = Counter(code)
    result = set()

    for key in rep:
        if rep[key] >= 2:
            result.add(key)

    return len(result) == 1



code1 = "arghh"
code2 = "haha"
code3 = "aaabbbcccc"

print(can_make_balanced(code1)) 
print(can_make_balanced(code2)) 
print(can_make_balanced(code3))
# Out:
# True
# False
# False

# %%
def find_treasure_indices(gold_amounts, target):
    hm = {}

    for i in range(len(gold_amounts)):
        complement = target - gold_amounts[i]

        if complement in hm:
            return [hm[complement], i]

        
        hm[gold_amounts[i]] = i


gold_amounts1 = [2, 7, 11, 15]
target1 = 9

gold_amounts2 = [3, 2, 4]
target2 = 6

gold_amounts3 = [3, 3]
target3 = 6

print(find_treasure_indices(gold_amounts1, target1))  
print(find_treasure_indices(gold_amounts2, target2))  
print(find_treasure_indices(gold_amounts3, target3))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]
